# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=42)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [47.13323967]
# 2.3302306410539453

# %%
# Using Ridge

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=10)
rr.fit(X,y)
print(rr.coef_)
print(rr.intercept_)
# Out:
# [41.9906212]
# 1.7961876226164755

# %%
rr1 = Ridge(alpha=100)
rr1.fit(X,y)
print(rr1.coef_)
print(rr1.intercept_)
# Out:
# [21.18627364]
# -0.3642714175995896

# %%
plt.plot(X,y,'b.')
plt.plot(X,lr.predict(X),color='red',label='alpha=0')
plt.plot(X,rr.predict(X),color='green',label='alpha=10')
plt.plot(X,rr1.predict(X),color='orange',label='alpha=100')
plt.legend()

# %% [markdown]
# # Conclusion
# Alpha = 0 can be considered overfitting.\
# Alpha = 10 seems to be more balanced (good fit).\
# Alpha = 100 shows underfitting.
